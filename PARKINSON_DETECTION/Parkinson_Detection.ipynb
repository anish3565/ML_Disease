# %%
# %%capture
# !mamba install -- upgrade scikit-learn=1.2.1
# !mamba install seaborn --y

# %%
# !pip install dtreeviz
# Out:
# Requirement already satisfied: dtreeviz in c:\users\dell\miniconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: graphviz>=0.9 in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz) (0.20.3)
# Requirement already satisfied: pandas in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz) (2.2.3)
# Requirement already satisfied: numpy in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz) (1.5.2)
# Requirement already satisfied: matplotlib in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz) (3.9.2)
# Requirement already satisfied: colour in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz) (8.3.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib->dtreeviz) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib->dtreeviz) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib->dtreeviz) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib->dtreeviz) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib->dtreeviz) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib->dtreeviz) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\miniconda3\lib\site-packages (from pandas->dtreeviz) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\miniconda3\lib\site-packages (from pandas->dtreeviz) (2024.2)
# Requirement already satisfied: colorama in c:\users\dell\miniconda3\lib\site-packages (from pytest->dtreeviz) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\dell\miniconda3\lib\site-packages (from pytest->dtreeviz) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\dell\miniconda3\lib\site-packages (from pytest->dtreeviz) (1.5.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dell\miniconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dell\miniconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\miniconda3\lib\site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %%
## Creating helper function for plotting¶
sns.set(style="whitegrid", color_codes=True)
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = 3*cm.max()/4
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
## Loading Data
data = pd.read_csv("parkinsons.data", sep=',', index_col='name') # assign index column to name
data.head()
# Out:
#                 MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# name
# phon_R01_S01_1      119.992       157.302        74.997         0.00784
# phon_R01_S01_2      122.400       148.650       113.819         0.00968
# phon_R01_S01_3      116.682       131.111       111.555         0.01050
# phon_R01_S01_4      116.676       137.871       111.366         0.00997
# phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#                 MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  \
# name
# phon_R01_S01_1           0.00007   0.00370   0.00554     0.01109
# phon_R01_S01_2           0.00008   0.00465   0.00696     0.01394
# phon_R01_S01_3           0.00009   0.00544   0.00781     0.01633
# phon_R01_S01_4           0.00009   0.00502   0.00698     0.01505
# phon_R01_S01_5           0.00011   0.00655   0.00908     0.01966
#
#                 MDVP:Shimmer  MDVP:Shimmer(dB)  ...  Shimmer:DDA      NHR  \
# name                                            ...
# phon_R01_S01_1       0.04374             0.426  ...      0.06545  0.02211
# phon_R01_S01_2       0.06134             0.626  ...      0.09403  0.01929
# phon_R01_S01_3       0.05233             0.482  ...      0.08270  0.01309
# phon_R01_S01_4       0.05492             0.517  ...      0.08771  0.01353
# phon_R01_S01_5       0.06425             0.584  ...      0.10470  0.01767
#
#                    HNR  status      RPDE       DFA   spread1   spread2  \
# name
# phon_R01_S01_1  21.033       1  0.414783  0.815285 -4.813031  0.266482
# phon_R01_S01_2  19.085       1  0.458359  0.819521 -4.075192  0.335590
# phon_R01_S01_3  20.651       1  0.429895  0.825288 -4.443179  0.311173
# phon_R01_S01_4  20.644       1  0.434969  0.819235 -4.117501  0.334147
# phon_R01_S01_5  19.649       1  0.417356  0.823484 -3.747787  0.234513
#
#                       D2       PPE
# name
# phon_R01_S01_1  2.301442  0.284654
# phon_R01_S01_2  2.486855  0.368674
# phon_R01_S01_3  2.342259  0.332634
# phon_R01_S01_4  2.405554  0.368975
# phon_R01_S01_5  2.332180  0.410335
#
# [5 rows x 23 columns]

# %%
print(data.shape)
# Out:
# (195, 23)

# %%
# Creating the correlation matrix
plt.figure(figsize=(12, 10))
mask = np.triu(np.ones_like(data.corr(), dtype=np.bool_))
sns.heatmap(data.corr(),vmin=-1, vmax=1,cmap='BrBG', mask=mask)
# Out:
# <Axes: >

# %%
# Modify the headmap plot to show correlation variables to the status
plt.figure(figsize=(10, 10))
heatmap = sns.heatmap(data.corr()[['status']].sort_values(by='status', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with Parkinson existance', fontdict={'fontsize':18}, pad=16);

# %%
X = data.drop('status', axis=1)
X.head()
# Out:
#                 MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# name
# phon_R01_S01_1      119.992       157.302        74.997         0.00784
# phon_R01_S01_2      122.400       148.650       113.819         0.00968
# phon_R01_S01_3      116.682       131.111       111.555         0.01050
# phon_R01_S01_4      116.676       137.871       111.366         0.00997
# phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#                 MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  \
# name
# phon_R01_S01_1           0.00007   0.00370   0.00554     0.01109
# phon_R01_S01_2           0.00008   0.00465   0.00696     0.01394
# phon_R01_S01_3           0.00009   0.00544   0.00781     0.01633
# phon_R01_S01_4           0.00009   0.00502   0.00698     0.01505
# phon_R01_S01_5           0.00011   0.00655   0.00908     0.01966
#
#                 MDVP:Shimmer  MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA  \
# name                                            ...
# phon_R01_S01_1       0.04374             0.426  ...   0.02971      0.06545
# phon_R01_S01_2       0.06134             0.626  ...   0.04368      0.09403
# phon_R01_S01_3       0.05233             0.482  ...   0.03590      0.08270
# phon_R01_S01_4       0.05492             0.517  ...   0.03772      0.08771
# phon_R01_S01_5       0.06425             0.584  ...   0.04465      0.10470
#
#                     NHR     HNR      RPDE       DFA   spread1   spread2  \
# name
# phon_R01_S01_1  0.02211  21.033  0.414783  0.815285 -4.813031  0.266482
# phon_R01_S01_2  0.01929  19.085  0.458359  0.819521 -4.075192  0.335590
# phon_R01_S01_3  0.01309  20.651  0.429895  0.825288 -4.443179  0.311173
# phon_R01_S01_4  0.01353  20.644  0.434969  0.819235 -4.117501  0.334147
# phon_R01_S01_5  0.01767  19.649  0.417356  0.823484 -3.747787  0.234513
#
#                       D2       PPE
# name
# phon_R01_S01_1  2.301442  0.284654
# phon_R01_S01_2  2.486855  0.368674
# phon_R01_S01_3  2.342259  0.332634
# phon_R01_S01_4  2.405554  0.368975
# phon_R01_S01_5  2.332180  0.410335
#
# [5 rows x 22 columns]

# %%
y=data['status']
y.head()
# Out:
# name
# phon_R01_S01_1    1
# phon_R01_S01_2    1
# phon_R01_S01_3    1
# phon_R01_S01_4    1
# phon_R01_S01_5    1
# Name: status, dtype: int64

# %%
y.value_counts(normalize=True)
# Out:
# status
# 1    0.753846
# 0    0.246154
# Name: proportion, dtype: float64

# %%
import seaborn as sns
from sklearn.manifold import TSNE

# Apply t-SNE to reduce the dimensions to 2
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)

# Create a DataFrame with the t-SNE-transformed data and class labels
tsne_df = pd.DataFrame(data=X_tsne, columns=['TSNE1', 'TSNE2'])
tsne_df['Class'] = y.values

# Visualize the data based on class using a scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=tsne_df, x='TSNE1', y='TSNE2', hue='Class', palette='Set2')
plt.title('t-SNE Visualization')
plt.show()

# %% [markdown]
# ### Data preparation

# %%
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=11)


# print the shape of train and test data
print("X_train shape: ", X_train.shape)
print("y_train shape: ", y_train.shape)
print("X_test shape: ", X_test.shape)
print("y_test shape: ", y_test.shape)
# Out:
# X_train shape:  (136, 22)
# y_train shape:  (136,)
# X_test shape:  (59, 22)
# y_test shape:  (59,)

# %% [markdown]
# ### K-NN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(X_test)
y_pred[0:10]
knn.predict_proba(X_test)[0:10]
# Out:
# array([[0.33333333, 0.66666667],
#        [0.66666667, 0.33333333],
#        [0.33333333, 0.66666667],
#        [0.33333333, 0.66666667],
#        [0.        , 1.        ],
#        [0.33333333, 0.66666667],
#        [0.        , 1.        ],
#        [1.        , 0.        ],
#        [1.        , 0.        ],
#        [1.        , 0.        ]])

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
plot_confusion_matrix(confusion_matrix(y_test, y_pred),classes=[ "Not Parkinson", " Parkinson"],title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[ 9  3]
#  [ 5 42]]

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.75      0.69        12
#            1       0.93      0.89      0.91        47
#
#     accuracy                           0.86        59
#    macro avg       0.79      0.82      0.80        59
# weighted avg       0.87      0.86      0.87        59
#
#
# Accuracy Score: 0.864406779661017

# %% [markdown]
# ### GridSearchCV

# %%
param_grid = {
    'n_neighbors': [3, 5, 7, 9],
}

# %%
knn=KNeighborsClassifier()

# %%
from sklearn.model_selection import GridSearchCV


grid_search = GridSearchCV(knn, param_grid, scoring='recall', cv=5)

grid_search
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9]}, scoring='recall')

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9]}, scoring='recall')

# %%
### Print the best parameters and score on validation data¶
print("Best Parameters: ", grid_search.best_params_)
print("Best Score: ", grid_search.best_score_)
# Out:
# Best Parameters:  {'n_neighbors': 9}
# Best Score:  0.97

# %%
y_pred = grid_search.best_estimator_.predict(X_test)

# %%
from sklearn.metrics import recall_score
recall = recall_score(y_test, y_pred)

recall
# Out:
# 0.9148936170212766

# %%
y_hat = grid_search.best_estimator_.predict(X)

# %%
knn = KNeighborsClassifier()
knn.fit(X,y)
# Out:
# KNeighborsClassifier()

# %%
y_hat =knn.predict(X)

# %%
plot_confusion_matrix(confusion_matrix(y, y_hat),classes=[ "Not Parkinson", " Parkinson"],title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[ 32  16]
#  [  5 142]]

# %%
# find true positives(tp)
tsne_df['label']=''
tsne_df['label'].iloc[np.where((y_hat == 1) & (y == 1))]="TP"
# find true negatives (tn)
tsne_df['label'].iloc[np.where((y_hat == 0) & (y == 0))]="TN"
# find false positives (fp)
tsne_df['label'].iloc[np.where((y_hat == 1) & (y == 0))]="FP"
# find false negatives (fp)
tsne_df['label'].iloc[np.where((y_hat == 0) & (y == 1))]="FN"

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=tsne_df, x='TSNE1', y='TSNE2', hue='Class', palette='Set2',style='label')
plt.title('t-SNE Visualization')
plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)
y_pred[0:10]
# Out:
# array([1, 0, 1, 1, 1, 1, 1, 0, 0, 0], dtype=int64)

# %%
lr.predict_proba(X_test)[0:10]
# Out:
# array([[0.2680232 , 0.7319768 ],
#        [0.69156536, 0.30843464],
#        [0.06766651, 0.93233349],
#        [0.38582447, 0.61417553],
#        [0.07229081, 0.92770919],
#        [0.26269941, 0.73730059],
#        [0.00913656, 0.99086344],
#        [0.51065081, 0.48934919],
#        [0.85892667, 0.14107333],
#        [0.90261685, 0.09738315]])

# %%
plot_confusion_matrix(confusion_matrix(y_test, y_pred),classes=[ "Not Parkinson", " Parkinson"],title='Confusion matrix')
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Confusion matrix, without normalization
# [[ 9  3]
#  [ 6 41]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67        12
#            1       0.93      0.87      0.90        47
#
#     accuracy                           0.85        59
#    macro avg       0.77      0.81      0.78        59
# weighted avg       0.86      0.85      0.85        59
#
#
# Accuracy Score: 0.847457627118644

# %%
coef=abs(lr.coef_[0])
plt.barh(X.columns, coef)
plt.show()

# %%
best_columns=X.columns[np.argsort(-1*coef)[0:5]]
best_columns
# Out:
# Index(['D2', 'MDVP:Shimmer(dB)', 'spread1', 'DFA', 'spread2'], dtype='object')

# %%
log_reg = LogisticRegression(max_iter=10000)
log_reg.fit(X_train[best_columns], y_train)

# Get the predicted probabilities for each class
y_pred_proba = log_reg.predict_proba(X_test[best_columns])

plot_confusion_matrix(confusion_matrix(y_test, y_pred),classes=[ "Not Parkinson", " Parkinson"],title='Confusion matrix')
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Confusion matrix, without normalization
# [[ 9  3]
#  [ 6 41]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67        12
#            1       0.93      0.87      0.90        47
#
#     accuracy                           0.85        59
#    macro avg       0.77      0.81      0.78        59
# weighted avg       0.86      0.85      0.85        59
#
#
# Accuracy Score: 0.847457627118644

# %% [markdown]
# ### Support Vector Machines (SVM)

# %%
from sklearn.svm import SVC
# Train the SVM classifier
svm = SVC()
svm.fit(X_train, y_train)

# Make predictions on the test set
y_hat = svm.predict(X_test)

# confusion_matri
plot_confusion_matrix(confusion_matrix(y_test, y_hat),classes=[ "Not Parkinson", " Parkinson"],title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[ 4  8]
#  [ 2 45]]

# %%
param_grid = {
    'C': [0.1, 1,],
    'gamma': [0.1, 1, 10],

}

# %%
from sklearn.svm import SVC
# Train the SVM classifier
svm = SVC()
# Create a GridSearchCV object
grid_search = GridSearchCV(svm, param_grid, scoring='recall', cv=2)

# Fit the GridSearchCV object to the training data
grid_search.fit(X_train, y_train)

# Print the best hyperparameters and the corresponding recall score
print("Best hyperparameters: ", grid_search.best_params_)
print("Best recall score: ", grid_search.best_score_)
# Out:
# Best hyperparameters:  {'C': 0.1, 'gamma': 0.1}
# Best recall score:  1.0

# %% [markdown]
# ### Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
# Create a Random Forest model
rf = RandomForestClassifier(random_state=123)

# Train the model on the training data
rf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = rf.predict(X_test)

# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 89.83%

# %%
### Perform grid search for RandomForest to tune the parameters
from sklearn.model_selection import GridSearchCV

# Define the parameter grid to search over
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [5, 10, 15],
    'max_features': ['sqrt', 'log2']
}

# Create a random forest classifier
rf = RandomForestClassifier(random_state=42)

# Create the GridSearchCV object
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5)

# Fit the GridSearchCV object to the data
grid_search.fit(X_train, y_train)
rf.fit(X_train, y_train)

# Print the best hyperparameters
print("Best parameters:", grid_search.best_params_)

# Get the best model
best_model = grid_search.best_estimator_
# Out:
# Best parameters: {'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100}

# %%
# plot the important features
feat_importances = pd.Series(rf.feature_importances_, index=X.columns)
feat_importances.sort_values().plot(kind='barh',color=['g','b'])
# Out:
# <Axes: >

# %%
import pickle

# Save the model to a file
filename = 'rf_model_parkinson'
pickle.dump(rf, open(filename, "wb"))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [2, 4],
    'min_samples_split': [2, 4],
    'min_samples_leaf': [1, 2]
}

# Create a decision tree classifier
dt = DecisionTreeClassifier()

# Use GridSearchCV to search for the best parameters
grid_search = GridSearchCV(dt, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Print the best parameters and best score
print("Best parameters:", grid_search.best_params_)
print("Best recall score:", grid_search.best_score_)
# Out:
# Best parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 2, 'min_samples_split': 4}
# Best recall score: 0.8891534391534393

# %%
clf=grid_search.best_estimator_
#same as
#clf = DecisionTreeClassifier(max_depth=2, min_samples_leaf=1, min_samples_split=2, criterion= 'entropy')
#clf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = clf.predict(X_test)

# %%
# !pip install dtreeviz

# %%
# !pip install dtreeviz==1.4.0
# Out:
# Requirement already satisfied: dtreeviz==1.4.0 in c:\users\dell\miniconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: graphviz>=0.9 in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz==1.4.0) (0.20.3)
# Requirement already satisfied: pandas in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz==1.4.0) (2.2.3)
# Requirement already satisfied: numpy in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz==1.4.0) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz==1.4.0) (1.5.2)
# Requirement already satisfied: matplotlib in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz==1.4.0) (3.9.2)
# Requirement already satisfied: colour in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz==1.4.0) (0.1.5)
# Requirement already satisfied: pytest in c:\users\dell\miniconda3\lib\site-packages (from dtreeviz==1.4.0) (8.3.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib->dtreeviz==1.4.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib->dtreeviz==1.4.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib->dtreeviz==1.4.0) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib->dtreeviz==1.4.0) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib->dtreeviz==1.4.0) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib->dtreeviz==1.4.0) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib->dtreeviz==1.4.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from matplotlib->dtreeviz==1.4.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\miniconda3\lib\site-packages (from pandas->dtreeviz==1.4.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\miniconda3\lib\site-packages (from pandas->dtreeviz==1.4.0) (2024.2)
# Requirement already satisfied: colorama in c:\users\dell\miniconda3\lib\site-packages (from pytest->dtreeviz==1.4.0) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\dell\miniconda3\lib\site-packages (from pytest->dtreeviz==1.4.0) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\dell\miniconda3\lib\site-packages (from pytest->dtreeviz==1.4.0) (1.5.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dell\miniconda3\lib\site-packages (from scikit-learn->dtreeviz==1.4.0) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dell\miniconda3\lib\site-packages (from scikit-learn->dtreeviz==1.4.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\miniconda3\lib\site-packages (from scikit-learn->dtreeviz==1.4.0) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz==1.4.0) (1.16.0)

# %%
# plot the tree
from dtreeviz.trees import dtreeviz

# Getting the list of variables
feature_names = list(X_train.columns)

# visualizing the tree
viz_model = dtreeviz.model(clf,
                           X_train=X_train, y_train=y_train,
                           feature_names=feature_names)

v = viz_model.view(fancy=True)     # render as SVG into internal object
v
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[154], line 2
#       1 # plot the tree
# ----> 2 from dtreeviz.trees import dtreeviz
#       4 # Getting the list of variables
#       5 feature_names = list(X_train.columns)
#
# ModuleNotFoundError: No module named 'dtreeviz'

# %%
# get a random point
rand = np.random.randint(0, len(X))
sample_point = X.iloc[rand,:].values

# visualizing the path for the point
v = viz_model.view(fancy=True,scale=1.5,x=sample_point,show_just_path=True)
v
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
